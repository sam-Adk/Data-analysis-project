# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/home/erick/Downloads/Procurement KPI Analysis Dataset.csv")

# %%
data
# Out:
#         PO_ID         Supplier  Order_Date Delivery_Date    Item_Category  \
# 0    PO-00001        Alpha_Inc  2023-10-17    2023-10-25  Office Supplies
# 1    PO-00002  Delta_Logistics  2022-04-25    2022-05-05  Office Supplies
# 2    PO-00003         Gamma_Co  2022-01-26    2022-02-15              MRO
# 3    PO-00004    Beta_Supplies  2022-10-09    2022-10-28        Packaging
# 4    PO-00005  Delta_Logistics  2022-09-08    2022-09-20    Raw Materials
# ..        ...              ...         ...           ...              ...
# 772  PO-00773  Delta_Logistics  2023-02-11    2023-02-20      Electronics
# 773  PO-00774        Alpha_Inc  2022-07-23           NaN  Office Supplies
# 774  PO-00775         Gamma_Co  2022-03-19    2022-04-07    Raw Materials
# 775  PO-00776    Beta_Supplies  2023-08-30    2023-09-11              MRO
# 776  PO-00777    Beta_Supplies  2023-12-09    2023-12-11  Office Supplies
#
#     Order_Status  Quantity  Unit_Price  Negotiated_Price  Defective_Units  \
# ...

# %%
data.head(5)
# Out:
#       PO_ID         Supplier  Order_Date Delivery_Date    Item_Category  \
# 0  PO-00001        Alpha_Inc  2023-10-17    2023-10-25  Office Supplies
# 1  PO-00002  Delta_Logistics  2022-04-25    2022-05-05  Office Supplies
# 2  PO-00003         Gamma_Co  2022-01-26    2022-02-15              MRO
# 3  PO-00004    Beta_Supplies  2022-10-09    2022-10-28        Packaging
# 4  PO-00005  Delta_Logistics  2022-09-08    2022-09-20    Raw Materials
#
#   Order_Status  Quantity  Unit_Price  Negotiated_Price  Defective_Units  \
# 0    Cancelled      1176       20.13             17.81              NaN
# 1    Delivered      1509       39.32             37.34            235.0
# 2    Delivered       910       95.51             92.26             41.0
# 3    Delivered      1344       99.85             95.52            112.0
# 4    Delivered      1180       64.07             60.53            171.0
#
#   Compliance
# 0        Yes
# 1        Yes
# 2        Yes
# 3        Yes
# 4         No

# %%
data.tail(5)
# Out:
#         PO_ID         Supplier  Order_Date Delivery_Date    Item_Category  \
# 772  PO-00773  Delta_Logistics  2023-02-11    2023-02-20      Electronics
# 773  PO-00774        Alpha_Inc  2022-07-23           NaN  Office Supplies
# 774  PO-00775         Gamma_Co  2022-03-19    2022-04-07    Raw Materials
# 775  PO-00776    Beta_Supplies  2023-08-30    2023-09-11              MRO
# 776  PO-00777    Beta_Supplies  2023-12-09    2023-12-11  Office Supplies
#
#     Order_Status  Quantity  Unit_Price  Negotiated_Price  Defective_Units  \
# 772    Delivered      1685       43.42             42.24            262.0
# 773    Delivered       445       68.94             60.35              7.0
# 774    Delivered       494       94.82             81.89             29.0
# 775    Delivered      1306       21.05             18.27            128.0
# 776    Delivered      1988      105.20             93.23            187.0
#
#     Compliance
# 772        Yes
# 773        Yes
# 774        Yes
# ...

# %%
data.columns
# Out:
# Index(['PO_ID', 'Supplier', 'Order_Date', 'Delivery_Date', 'Item_Category',
#        'Order_Status', 'Quantity', 'Unit_Price', 'Negotiated_Price',
#        'Defective_Units', 'Compliance'],
#       dtype='object')

# %%
#finding out if there is any missing values in the dataset

# %%
data.isnull().sum()
# Out:
# PO_ID                 0
# Supplier              0
# Order_Date            0
# Delivery_Date        87
# Item_Category         0
# Order_Status          0
# Quantity              0
# Unit_Price            0
# Negotiated_Price      0
# Defective_Units     136
# Compliance            0
# dtype: int64

# %%
data=data.dropna(how='all')

# %%
#cleaning and removing all mising values

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# PO_ID               0
# Supplier            0
# Order_Date          0
# Delivery_Date       0
# Item_Category       0
# Order_Status        0
# Quantity            0
# Unit_Price          0
# Negotiated_Price    0
# Defective_Units     0
# Compliance          0
# dtype: int64

# %%
data.head(5)
# Out:
#       PO_ID         Supplier  Order_Date Delivery_Date    Item_Category  \
# 1  PO-00002  Delta_Logistics  2022-04-25    2022-05-05  Office Supplies
# 2  PO-00003         Gamma_Co  2022-01-26    2022-02-15              MRO
# 3  PO-00004    Beta_Supplies  2022-10-09    2022-10-28        Packaging
# 4  PO-00005  Delta_Logistics  2022-09-08    2022-09-20    Raw Materials
# 5  PO-00006    Epsilon_Group  2022-08-17    2022-08-29              MRO
#
#   Order_Status  Quantity  Unit_Price  Negotiated_Price  Defective_Units  \
# 1    Delivered      1509       39.32             37.34            235.0
# 2    Delivered       910       95.51             92.26             41.0
# 3    Delivered      1344       99.85             95.52            112.0
# 4    Delivered      1180       64.07             60.53            171.0
# 5    Delivered      1145       69.21             63.57             39.0
#
#   Compliance
# 1        Yes
# 2        Yes
# 3        Yes
# 4         No
# 5        Yes

# %%
data.groupby('Supplier')['Defective_Units'].max()
# Out:
# Supplier
# Alpha_Inc          100.0
# Beta_Supplies      221.0
# Delta_Logistics    321.0
# Epsilon_Group      100.0
# Gamma_Co           108.0
# Name: Defective_Units, dtype: float64

# %%
data.dtypes
# Out:
# PO_ID                object
# Supplier             object
# Order_Date           object
# Delivery_Date        object
# Item_Category        object
# Order_Status         object
# Quantity              int64
# Unit_Price          float64
# Negotiated_Price    float64
# Defective_Units     float64
# Compliance           object
# dtype: object

# %%
#now am going to check wich suppliers had the most expensive units

# %%
data.head(20)
# Out:
#        PO_ID         Supplier  Order_Date Delivery_Date    Item_Category  \
# 1   PO-00002  Delta_Logistics  2022-04-25    2022-05-05  Office Supplies
# 2   PO-00003         Gamma_Co  2022-01-26    2022-02-15              MRO
# 3   PO-00004    Beta_Supplies  2022-10-09    2022-10-28        Packaging
# 4   PO-00005  Delta_Logistics  2022-09-08    2022-09-20    Raw Materials
# 5   PO-00006    Epsilon_Group  2022-08-17    2022-08-29              MRO
# 6   PO-00007         Gamma_Co  2022-05-23    2022-06-03              MRO
# 7   PO-00008        Alpha_Inc  2022-04-15    2022-04-29              MRO
# 8   PO-00009         Gamma_Co  2023-11-24    2023-11-28    Raw Materials
# 9   PO-00010         Gamma_Co  2023-07-13    2023-07-25    Raw Materials
# 10  PO-00011    Epsilon_Group  2022-03-31    2022-04-15    Raw Materials
# 11  PO-00012    Beta_Supplies  2023-08-28    2023-09-11    Raw Materials
# 12  PO-00013    Beta_Supplies  2023-03-09    2023-03-26      Electronics
# ...

# %%
data.tail()
# Out:
#         PO_ID         Supplier  Order_Date Delivery_Date    Item_Category  \
# 771  PO-00772    Beta_Supplies  2023-01-20    2023-02-02      Electronics
# 772  PO-00773  Delta_Logistics  2023-02-11    2023-02-20      Electronics
# 774  PO-00775         Gamma_Co  2022-03-19    2022-04-07    Raw Materials
# 775  PO-00776    Beta_Supplies  2023-08-30    2023-09-11              MRO
# 776  PO-00777    Beta_Supplies  2023-12-09    2023-12-11  Office Supplies
#
#     Order_Status  Quantity  Unit_Price  Negotiated_Price  Defective_Units  \
# 771    Delivered       226      102.47             99.16             28.0
# 772    Delivered      1685       43.42             42.24            262.0
# 774    Delivered       494       94.82             81.89             29.0
# 775    Delivered      1306       21.05             18.27            128.0
# 776    Delivered      1988      105.20             93.23            187.0
#
#     Compliance
# 771        Yes
# 772        Yes
# 774        Yes
# ...

# %%
data.groupby('Supplier')[''].max()
# Out:
# Supplier
# Alpha_Inc          109.17
# Beta_Supplies      107.51
# Delta_Logistics    108.63
# Epsilon_Group      108.02
# Gamma_Co           106.20
# Name: Unit_Price, dtype: float64

# %%
#finding out the mean of each items

# %%
data.groupby('Item_Category')['Unit_Price'].mean()
# Out:
# Item_Category
# Electronics        55.779224
# MRO                61.238333
# Office Supplies    58.878115
# Packaging          55.333704
# Raw Materials      61.098763
# Name: Unit_Price, dtype: float64

# %%
data.groupby('Item_Category')['Negotiated_Price'].mean()
# Out:
# Item_Category
# Electronics        51.517500
# MRO                56.501587
# Office Supplies    54.529180
# Packaging          50.700093
# Raw Materials      56.270412
# Name: Negotiated_Price, dtype: float64

# %%
#finding top 5 most common suppliers

# %%
data['Supplier'].value_counts().head()
# Out:
# Epsilon_Group      126
# Beta_Supplies      123
# Gamma_Co           115
# Delta_Logistics    111
# Alpha_Inc           94
# Name: Supplier, dtype: int64

# %%
#checking the suppliers with the most deliveries

# %%
deliveries_counts=data.groupby('Supplier').size()

# %%
deliveries_counts
# Out:
# Supplier
# Alpha_Inc           94
# Beta_Supplies      123
# Delta_Logistics    111
# Epsilon_Group      126
# Gamma_Co           115
# dtype: int64

# %%
deliveries_counts.max()
# Out:
# 126

# %%
data.head(2)
# Out:
#       PO_ID         Supplier  Order_Date Delivery_Date    Item_Category  \
# 1  PO-00002  Delta_Logistics  2022-04-25    2022-05-05  Office Supplies
# 2  PO-00003         Gamma_Co  2022-01-26    2022-02-15              MRO
#
#   Order_Status  Quantity  Unit_Price  Negotiated_Price  Defective_Units  \
# 1    Delivered      1509       39.32             37.34            235.0
# 2    Delivered       910       95.51             92.26             41.0
#
#   Compliance
# 1        Yes
# 2        Yes

# %%
data['Negotiated_Price'].hist()
plt.xlabel('Defective_Units')
plt.ylabel('Negotiated_Price')
plt.title('Distribution of Negotiated Price')
plt.show()

# %%
sns.histplot(data['Negotiated_Price'], kde=True)
plt.title('Histogram ')
plt.xlabel('Unit_Price')
plt.ylabel('Item_category')
plt.show()
