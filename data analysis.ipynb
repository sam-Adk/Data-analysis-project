# %% [markdown]
# # Data Analytics with python

# %%
import pandas as pd

# %%
data=pd.read_csv("/home/erick/Downloads/weather.csv")

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %% [markdown]
# # head

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# #shape

# %%
data.shape
# Out:
# (366, 22)

# %% [markdown]
# # index

# %%
data.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %% [markdown]
# #columns

# %%
data.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
data.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %% [markdown]
# # unique

# %%
data["Rainfall"].unique()
# Out:
# array([ 0. ,  3.6, 39.8,  2.8,  0.2, 16.2,  1.2,  0.6,  0.4, 25.8, 22.6,
#         4.2,  6.6,  4. ,  5.4,  1.4,  3.4,  6.4, 11. , 17.4, 14.4,  2. ,
#         4.8, 18.8, 12.2,  0.8,  5.2,  2.2,  1.8,  9. ,  1. ,  4.4, 10.4,
#         3. , 19.8,  2.6,  7.2,  3.8,  6.2, 16.8,  1.6, 19.2,  7.4,  9.8,
#         7.6,  8.2, 13.2])

# %% [markdown]
# # count

# %%
data.count()
# Out:
# MinTemp          366
# MaxTemp          366
# Rainfall         366
# Evaporation      366
# Sunshine         363
# WindGustDir      363
# WindGustSpeed    364
# WindDir9am       335
# WindDir3pm       365
# WindSpeed9am     359
# WindSpeed3pm     366
# Humidity9am      366
# Humidity3pm      366
# Pressure9am      366
# Pressure3pm      366
# Cloud9am         366
# Cloud3pm         366
# Temp9am          366
# Temp3pm          366
# RainToday        366
# RISK_MM          366
# RainTomorrow     366
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
# ...

# %%
data.head(2)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
#
# [2 rows x 22 columns]

# %%
#std

# %%
data.Pressure9am.std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of 0      1019.7
# 1      1012.4
# 2      1009.5
# 3      1005.5
# 4      1018.3
#         ...
# 361    1016.1
# 362    1020.0
# 363    1024.0
# 364    1021.0
# 365    1009.6
# Name: Pressure9am, Length: 366, dtype: float64>

# %%
#variation

# %%
data.Rainfall.var()
# Out:
# 17.857382139381833

# %%
#value counts

# %%
data.head(2)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
#
# [2 rows x 22 columns]

# %%
data["Evaporation"].value_counts()
# Out:
# 2.2     21
# 2.8     19
# 1.4     15
# 1.8     14
# 2.6     14
# 1.6     13
# 6.6     13
# 3.4     12
# 4.4     11
# 2.4     11
# 5.8     10
# 2.0     10
# 4.8      9
# 6.4      9
# 7.2      9
# 5.4      9
# 6.8      8
# 4.2      8
# 5.6      8
# 3.0      8
# 1.2      8
# 5.2      8
# 6.2      8
# 3.2      7
# 5.0      7
# 4.0      6
# 7.8      6
# 6.0      6
# 9.4      5
# 3.6      5
# 0.6      5
# 3.8      5
# 7.4      5
# 8.8      5
# 10.4     4
# 0.8      4
# 8.4      4
# 9.0      4
# 9.6      4
# 7.6      4
# 10.0     3
# 1.0      3
# 4.6      3
# 0.2      2
# 9.2      2
# 8.2      2
# 8.0      2
# 8.6      1
# 10.2     1
# 12.4     1
# 13.8     1
# 12.6     1
# 11.4     1
# 7.0      1
# 11.6     1
# Name: Evaporation, dtype: int64

# %%
#finding instances where windpeed at 9am is above 24 and cloud at 9am is 25:

# %%
data.head(2)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
#
# [2 rows x 22 columns]

# %%
(data['WindSpeed9am'] > 24) & (data['Cloud9am'] == 25)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 361    False
# 362    False
# 363    False
# 364    False
# 365    False
# Length: 366, dtype: bool

# %%
#what is the mean value of each column against each column

# %%
data.head(2)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
#
# [2 rows x 22 columns]

# %%
data.groupby('Sunshine').mean()
# Out:
#           MinTemp  MaxTemp  Rainfall  Evaporation  WindGustSpeed  \
# Sunshine
# 0.0         10.75    15.70      3.94          4.0           30.9
# 0.1         15.10    20.40      0.00          9.6           39.0
# 0.2          9.05    15.75     11.70          1.9           38.0
# 0.3         16.80    22.80      9.00          2.8           30.0
# 0.4         13.85    21.25      5.50          5.1           34.5
# ...           ...      ...       ...          ...            ...
# 13.1        10.10    31.20      0.00          8.8           41.0
# 13.2        15.20    30.75      7.20          9.1           36.0
# 13.3        17.50    35.80      0.00          9.4           57.0
# 13.5        17.00    33.80      2.00          9.0           52.0
# 13.6        14.10    32.55      0.00          9.0           30.5
#
#           WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# Sunshine
# 0.0                7.2          11.1         90.1         81.7      1018.06
# ...

# %%
#what is the minimum and maximum value of each column against each 'weather condition'

# %%
data.head(2)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
#
# [2 rows x 22 columns]

# %%
data.groupby('Rainfall').max(5)
# Out:
#           MinTemp  MaxTemp  Evaporation  Sunshine  WindGustSpeed  \
# Rainfall
# 0.0          20.9     35.8         13.8      13.6           83.0
# 0.2          16.6     31.7          7.8      12.7           61.0
# 0.4          16.4     24.3          9.2       9.9           50.0
# 0.6          15.5     32.3          7.4      13.0           54.0
# 0.8          15.9     19.9          5.6      11.7           70.0
# 1.0          13.6     27.4          2.8       9.4           65.0
# 1.2          11.7     30.0          7.2      10.1           52.0
# 1.4          10.8     21.7          2.8      10.6           59.0
# 1.6           8.7     19.7          5.2       8.0           98.0
# 1.8          18.2     24.8          8.0       4.3           50.0
# 2.0          17.0     33.8          9.0      13.5           78.0
# 2.2          16.0     23.8          5.4       6.2           30.0
# 2.6           7.0     14.3          9.6       9.7           63.0
# ...

# %%
data.groupby('Rainfall').min(5)
# Out:
#           MinTemp  MaxTemp  Evaporation  Sunshine  WindGustSpeed  \
# Rainfall
# 0.0          -5.3      8.7          0.6       0.0           13.0
# 0.2          -2.6     11.0          1.2       0.0           17.0
# 0.4          -3.5      7.6          1.2       0.0           26.0
# 0.6           0.4     13.0          0.8       1.9           28.0
# 0.8           3.0     11.1          0.6       0.0           20.0
# 1.0           0.2      9.7          1.8       0.7           31.0
# 1.2           2.4     11.6          1.4       7.2           35.0
# 1.4          -1.6     10.7          0.8       9.1           48.0
# 1.6           2.9      8.4          1.4       7.7           59.0
# 1.8           4.5     16.0          3.0       0.0           33.0
# 2.0           5.3     11.7          3.2       5.6           39.0
# 2.2          16.0     23.8          5.4       6.2           30.0
# 2.6           7.0     14.3          9.6       9.7           63.0
# ...

# %%
# %history -f Data analysis.py
# Out:
# File 'Data' exists. Overwrite? no
# Aborting.
